# %%
import numpy as np
import matplotlib.pyplot as plt
import jax

from chromatix.ops import init_plane_resample
import chromatix.functional as cx

import phantom
from simulate import apply_psf
from phantom import Material
from inputs.xscatter import get_wavelen, get_wavenum
from matdecomp import spbi_material_basis
from simulate import simulate_projection

from pipeline import run_material_decomposition
import itertools
import pandas as pd
import seaborn as sns

adip = Material('adipose', 'H(11.2)C(61.9)N(1.7)O(25.1)', 0.93)
gland = Material('gland', 'H(10.2)C(18.4)N(3.2)O(67.6)', 1.04)
tissue = Material('tissue', 'H(10.2)C(14.3)N(3.4)O(70.8)Na(0.2)P(0.3)S(0.3)Cl(0.2)K(0.3)', 1.06)   
bone = Material('bone', 'H(3.4)C(15.5)N(4.2)O(43.5)Na(0.1)Mg(0.2)P(10.3)S(0.3)Ca(22.5)', 1.92)

# %%
'''
plt.rcParams.update({
    'figure.dpi': 300,
    'font.size':10,
    'axes.titlesize':10,
    'axes.labelsize':8,
    'axes.linewidth': .5,
    'xtick.labelsize':8,
    'ytick.labelsize':8,
    'legend.fontsize': 8,
    'image.cmap':'gray'
})
'''

from cycler import cycler
custom_cycler = cycler('color', ['#0072B2', '#009E73', '#F0E442', '#D55E00', '#CC79A7'])  # color blind

plt.rcParams.update({
    'figure.dpi': 300,
    'font.size':10,
    'axes.titlesize':10,
    'axes.labelsize':8,
    'axes.linewidth': .5,
    'axes.prop_cycle': custom_cycler,
    'xtick.top': True, 
    'ytick.right': True, 
    'xtick.direction': 'in', 
    'ytick.direction': 'in',
    'xtick.labelsize':8,
    'ytick.labelsize':8,
    'legend.fontsize': 8,
    'lines.linewidth':1,
    'image.cmap':'gray',
    'text.usetex': True,
    'font.family': 'serif'
})

# %%
# %%time

### PARAMETERS
energy = 20  #energy [keV] for evaluating the delta and beta values

#phantom dimensions and resolution
N = 256     #num voxels in x,y direction
# Nz = 50
Nz = 100     #num voxels in z direction (smaller = less memory use)
dx = 2e-6     #voxel size in x,y direction [m]
# dz = 10e-6  
dz = 0.0002    #voxel size in z direction (in this case, 200 micrometer)

thickness = Nz*dz    #total axial (z) thickness [m] - for mammo, this should be a few cm

#material dictionary mapping labels from binary volume to Material objects 
mat_dict = {0:gland, 1:adip}
mat_frac = 0.5  #fraction of one material in the binary mixture (used for thresholding)

#Ellipsoidal structural mask for realistic projection shape
### GLJ note - this is causing artifacts in the simulations when R > 0. Need to fix
### For now use struct = 1 or flat ellipsoid instead
struct = phantom.tmap_ellipsoid(N, 0.35*N, 0.42*N, angle=20)   
struct2 = np.zeros(struct.shape)
struct2[struct>1e-3] = 1    #"flattens" the ellipsoid
struct = struct2


### MAKE PHANTOM

np.random.seed(200)  #for reproducibility of the generated phantom texture

#by default, vol is a cube, so we truncate in the z-direction with [:Nz]
vol = phantom.make_phantom(N, dx, alpha=4)[:Nz]  

#binarize the volume into two materials based on material fraction
vol_mask = phantom.thresh_texture(vol, mat_frac)

#convert material labels into delta and beta volumes at the given energy
#output shape: (Ne, Nz, N, N); here Ne = 1 since energy is scalar
vol_delta, vol_beta = phantom.make_db_vol(vol_mask, mat_dict, energy)

#generate parallel-beam projections along z-axis.
#N.B.: the volumes are 4D now (first axis is energy, but we only have one energy now.)
#so we index the first axis with 0.
proj_delta_flat = np.sum(vol_delta[0], axis=0)     #be careful with thickness element! 
proj_beta_flat = np.sum(vol_beta[0], axis=0)

#add the structure envelope to give our phantom more realistic geometry.
proj_delta = struct * proj_delta_flat
proj_beta = struct * proj_beta_flat


### DISPLAY RESULTS

fig, ax = plt.subplots(1, 2, figsize=[8,3], layout='constrained')
fig.suptitle(f'Energy = {energy} keV', fontweight='bold')

ax[0].set_title(r'$\delta$')
m = ax[0].imshow(proj_delta)
fig.colorbar(m, ax=ax[0])

ax[1].set_title(r'$\beta$')
m = ax[1].imshow(proj_beta)
fig.colorbar(m, ax=ax[1])

plt.show()
# Out:
# CPU times: total: 5.44 s
# Wall time: 6.03 s

# %% [markdown]
# # Simulation functions

# %%
# %%time

#changed to 5cm breast thickness
energy = 20     #keV
R = 0.1     #propagation distance [m]
dx = 2e-6     #phantom pixel size [m]
det_dx = 5e-6
N = 256
Nz = 250     #for 5 cm
thickness = 0.05    #m
dz = thickness / Nz
det_N = int((dx * N) // det_dx)

print(f'phantom FOV = {dx*N*1e6:.1f} µm,  detector FOV = {det_dx*det_N*1e6:.1f} µm')

#scaling coefficient (equal to dz)
c = dz

#run the simulation
img = simulate_projection(
    proj_beta * c, proj_delta * c,
    dx, det_N, det_dx, energy, R,
    det_psf='gaussian', det_fwhm=5e-6,
    I0=None  #no Poisson noise
)

#plot raw image
plt.figure(figsize=(5, 4))
plt.imshow(img, cmap='gray')
plt.colorbar(label='Intensity')
plt.title("Raw projection (5 cm tissue)")
plt.axis('off')
plt.show()
# Out:
# phantom FOV = 512.0 µm,  detector FOV = 510.0 µm
# CPU times: total: 781 ms
# Wall time: 596 ms

# %% [markdown]
# # Multiple-energy simulation (for material decomposition)

# %% [markdown]
# ## First — simulate images with different $E$

# %%
# %%time 


### Inputs

energies = np.array([20, 25])    #[keV]
R = 1e-2    #propagation distance [m]

mat_dict = {0: gland, 1: adip}
mat_frac = 0.5  

#x-y plane
N = 256     
dx = 2e-6   

#z axis (propagation direction)
Nz = 250    
thickness = 0.05     #breast thickness [m] = 5cm
dz = thickness / Nz

#detector features
det_N = 100
det_dx = 5e-6

#phantom structure
struct = np.zeros([N, N])
struct[phantom.tmap_ellipsoid(N, 0.35*N, 0.42*N, angle=20) > 1e-3] = 1  


### Simulate

np.random.seed(33)
vol = phantom.make_phantom(N, dx, alpha=4)[:Nz]  
vol_mask = phantom.thresh_texture(vol, mat_frac)

imgs = []
for energy in energies:
    vol_delta, vol_beta = phantom.make_db_vol(vol_mask, mat_dict, energy)

    proj_delta_flat = np.sum(vol_delta[0], axis=0)
    proj_beta_flat = np.sum(vol_beta[0], axis=0)

    proj_delta = dz * struct * proj_delta_flat
    proj_beta = dz * struct * proj_beta_flat

    img = simulate_projection(
        proj_beta, proj_delta,
        dx, det_N, det_dx, energy, R,
        det_psf='gaussian', det_fwhm=5e-6, I0=1e5
    )
    imgs.append(img)

imgs = np.array(imgs)


###raw visualization

fig, ax = plt.subplots(1, len(energies), figsize=[3.1 * len(energies), 3], layout='constrained')
fig.suptitle('Raw simulation images', fontweight='bold')
for i in range(len(energies)):
    m = ax[i].imshow(imgs[i], cmap='gray')
    ax[i].set_title(f'{energies[i]} keV')
    ax[i].axis('off')
fig.colorbar(m, ax=ax)
plt.show()
# Out:
# CPU times: total: 6.17 s
# Wall time: 7.01 s

# %% [markdown]
# ## Second — call material decomposition function `spbi_material_basis()`

# %%
# %%time


#define the material basis
mat1 = mat_dict[0]
mat2 = mat_dict[1]

#convert material deltas and betas to format for Schaff code
ds1, bs1 = mat1.db(energies)
ds2, bs2 = mat2.db(energies)
ds = -np.array([ds1, ds2]) 
mus = 2 * np.array([bs1, bs2]) * get_wavenum(energies)

#decompose
bmis = spbi_material_basis(imgs, R, det_dx, ds.T, mus.T)    #don't forget to transpose ds and mus!

#impose physical constraint
bmis = bmis.clip(0, None)

#show -- how do the intensity scales compare to `thickness`? 
print(f'true thickness = {thickness} m')

bmi_kw = {'vmin':0, 'vmax':2*thickness, 'cmap':'bwr'}

fig, ax = plt.subplots(1, 2, figsize=[7,3], layout='constrained')
fig.suptitle('Basis material images (projected thickness)', fontweight='bold')
for i, mat in enumerate([mat1, mat2]):
    m = ax[i].imshow(bmis[i], **bmi_kw)
    ax[i].set_title(mat.name)
    ax[i].axis('off')
    fig.colorbar(m, ax=ax[i])
plt.show()
# Out:
# true thickness = 0.05 m
# CPU times: total: 578 ms
# Wall time: 591 ms

# %% [markdown]
# ## Visually compare the material decomposition to the ground truth
# Note this is at the phantom resolution, so it will not only be perfectly accurate, it will be much sharper of an image!

# %%
# %%time


gt_bmi1 = dz * struct * np.sum(vol_mask == 0, axis=0)
gt_bmi2 = dz * struct * np.sum(vol_mask == 1, axis=0)

fig, ax = plt.subplots(1, 2, figsize=[7,3], layout='constrained')
fig.suptitle('True material projections', fontweight='bold')
for i, mat in enumerate([mat1, mat2]):
    m = ax[i].imshow([gt_bmi1, gt_bmi2][i], **bmi_kw)     #kw defined above
    ax[i].set_title(mat.name)
    ax[i].axis('off')
    fig.colorbar(m, ax=ax[i])
plt.show()
# Out:
# CPU times: total: 750 ms
# Wall time: 777 ms

# %% [markdown]
# # TO-DO:
# - Clean up code (maybe write single function that goes directly from `energies` and `R` -> `bmis` (basis material images). This will make your life easier later. Or maybe just move the simulate projection function to `simulate.py`.
# - Come up with a single metric ``figure of merit" (FOM) to assess how good the results are (calculate ground truth fraction $F_{gt}$ and estimated fraction from material decomposition $F_{md}$, then maybe your FOM can be something like % difference)
# - Note that if you use `I0`=0, then `R=0` should give a nearly perfect material decomposition. It's when you add noise (Poisson counting statistics from your "I0" incident photons) that phase contrast (i.e. `R>0`) becomes useful. You can leave I0=1e5 for now. To see the effect, try re-running the material decomp code above with `R=0`.
#
# Measure the FOM for some different **imaging system** input parameters:
# 1. Energies `energies` should be in range 15–35 keV. They should always be two different energies.
# 2. Distances `R` should be in range 0–20 cm. (Smaller might be better for now).
# 3. Try "small" (2 micron), "medium" (5 micron), and "large" (10 micron) `det_dx`.
#
# After this, try varying different **material** parameters:
# 1. Test $F_{gt}$ from 0.2 to 0.8 (or look up realistic ranges, maybe following the BIRADs classification into four breast density types)
# 2. Test `thickness` from 1 to 5 cm (or look up realistic ranges, 1 cm might be small but I am curious)
# 3. Test different $\alpha$ (textures, formerly the $\beta$ parameter)
#
# Explore methods for neatly presenting the key findings (show some example images and BMIs, but mainly focus on showing trends in your FOM or maybe how $F_{md}$ varies as a function of $F_{gt}$.
#
# To get error bars, you can measure the FOM for many different random seeds. Just make sure to re-measure $F_{gt}$ *after* you generate the phantom for a given random seed.
#
# You can also try exploring different `I0`, which varies the noise level. Larger values (more counts) should reduce the noise level, while smaller values (fewer counts) will make your images noisier. I expect smaller `I0` will make larger `R` perform relatively better.

# %%
# %%time


results = run_material_decomposition(
    (20, 25),
    R=0.1,
    det_dx=5e-6,
    thickness=0.05     #5 cm
)
print("FOM:", results['fom'], "Fgt:", results['Fgt'], "Fmd:", results['Fmd'])
# Out:
# FOM: 19.856138835580317 Fgt: 0.46064126934059374 Fmd: 0.5521068393148415
# CPU times: total: 5.5 s
# Wall time: 4.89 s

# %%
#N.B.:
#FOM (%)	Interpretation
#< 5%	Excellent accuracy
#5–15%	Good, acceptable for many imaging systems
#15–25%	Fair, showing moderate deviation
#> 25%	Poor accuracy — model may need tuning

# %%
# %%time


#sweep parameters
Rs = [0.0, 0.01, 0.05, 0.1, 0.15, 0.2]
det_dxs = [2e-6, 5e-6, 1e-5]
energy_pairs = [(15, 20), (20, 25), (25, 30), (30, 35)]
alphas = [2, 4, 6]

#fixed 5 cm tissue thickness
thickness = 0.05    #meters

results = []

for R, det_dx, energies, alpha in itertools.product(Rs, det_dxs, energy_pairs, alphas):
    res = run_material_decomposition(
        energies=energies,
        R=R,
        det_dx=det_dx,
        thickness=thickness,
        alpha=alpha
    )
    results.append({
        'energies': energies,
        'R': R,
        'det_dx': det_dx,
        'alpha': alpha,
        **res
    })

#save to CSV
df = pd.DataFrame(results)
df.to_csv("fom_sweep_thickness_5cm.csv", index=False)
# Out:
# CPU times: total: 30min 28s
# Wall time: 28min 3s

# %%
# %%time


df = pd.read_csv("fom_sweep_thickness_5cm.csv")

#making sure'energies' column is correctly formatted as tuples
df['energies'] = df['energies'].apply(lambda x: tuple(eval(x)) if isinstance(x, str) else tuple(x))

#unique energy pairs
energy_pairs = df['energies'].drop_duplicates()

for pair in energy_pairs:
    for alpha in df['alpha'].unique():
        subset = df[(df['energies'] == pair) & (df['alpha'] == alpha)]

        if subset.empty:
            print(f"Skipping empty subset for energies: {pair}, alpha: {alpha}")
            continue

        pivoted = subset.pivot(index='R', columns='det_dx', values='fom')

        if pivoted.empty:
            print(f"Empty pivot table for energies: {pair}, alpha: {alpha}")
            continue

        plt.figure(figsize=(6, 4))
        sns.heatmap(pivoted, annot=True, fmt=".1f", cmap='viridis')
        plt.title(f"FOM vs R and det_dx\nEnergies: {pair[0]} / {pair[1]} keV, α = {alpha}")
        plt.xlabel("Detector pixel size (m)")
        plt.ylabel("Propagation distance R (m)")
        plt.tight_layout()
        plt.show()
# Out:
# CPU times: total: 11.7 s
# Wall time: 12.3 s

# %%
# %%time

for pair in df['energies'].drop_duplicates():
    if isinstance(pair, str):
        pair = eval(pair)
    
    subset = df[df['energies'] == pair]
    plt.figure(figsize=(6, 4))
    for dx in sorted(subset['det_dx'].unique()):
        line = subset[subset['det_dx'] == dx]
        plt.plot(line['R'], line['fom'], marker='o', label=f'det_dx={dx*1e6:.0f} μm')

    plt.title(f"FOM vs R at different det_dx\nEnergies: {pair[0]} / {pair[1]} keV")
    plt.xlabel("Propagation distance R (m)")
    plt.ylabel("FOM (%)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# CPU times: total: 3.22 s
# Wall time: 3.25 s

# %%
# %%time


mean_fom = df.groupby('energies')['fom'].mean().sort_values()
mean_fom.plot(kind='bar', figsize=(6,4), color='teal')
plt.title("Mean FOM across energy pairs")
plt.ylabel("Mean FOM (%)")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# CPU times: total: 734 ms
# Wall time: 865 ms

# %%
avg_fom_per_energy = df.groupby("energies")["fom"].mean()
print(avg_fom_per_energy)
# Out:
# energies
# (15, 20)    77.054415
# (20, 25)    37.108126
# (25, 30)    25.548239
# (30, 35)    76.006333
# Name: fom, dtype: float64

# %%
# %%time

## sweep parameters
mat_fracs = [0.2, 0.4, 0.6, 0.8]
thicknesses = [0.01, 0.03, 0.05]     #1 cm to 5 cm
alphas = [2, 4, 6]
I0s = [1e3, 1e4, 1e5]
seeds = [10, 20, 30]

#fixed imaging setup
energies = (25, 30)     #picked these energies cuz lowest FOM earlier
R = 0.1
det_dx = 5e-6

results = []

for mat_frac, thickness, alpha, I0, seed in itertools.product(mat_fracs, thicknesses, alphas, I0s, seeds):
    try:
        res = run_material_decomposition(
            energies=energies,
            R=R,
            det_dx=det_dx,
            mat_frac=mat_frac,
            thickness=thickness,
            seed=seed,
            I0=I0,
            alpha=alpha
        )
        results.append({
            'mat_frac': mat_frac,
            'thickness': thickness,
            'alpha': alpha,
            'I0': I0,
            'seed': seed,
            **res
        })
    except Exception as e:
        print(f"Failed: mat_frac={mat_frac}, thickness={thickness}, alpha={alpha}, I0={I0}, seed={seed}")
        print(e)

# Save to CSV
df = pd.DataFrame(results)
df.to_csv("fom_sweep_extended.csv", index=False)
print("Saved to fom_sweep_extended.csv")
# Out:
# Saved to fom_sweep_extended.csv
# CPU times: total: 32min 9s
# Wall time: 28min 22s

# %%
df = pd.read_csv("fom_sweep_extended.csv")

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df, x='mat_frac', y='fom')
plt.title("FOM vs. material fraction (Fgt)")
plt.xlabel("True material fraction (Fgt)")
plt.ylabel("FOM (%)")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df, x='thickness', y='fom')
plt.title("FOM vs. thickness")
plt.xlabel("Phantom thickness (m)")
plt.ylabel("FOM (%)")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df, x='I0', y='fom')
plt.title("FOM vs. photon count (I0)")
plt.xlabel("I0")
plt.ylabel("FOM (%)")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df, x='alpha', y='fom')
plt.title("FOM vs. alpha")
plt.xlabel("alpha")
plt.ylabel("FOM (%)")
plt.tight_layout()
plt.show()

# %%
# %%time

#round thickness values to avoid floating-point precision issues
df['thickness'] = df['thickness'].round(5)

#group by material fraction and thickness, compute mean and std of FOM
summary = df.groupby(['mat_frac', 'thickness']).agg({'fom': ['mean', 'std']}).reset_index()
summary.columns = ['mat_frac', 'thickness', 'fom_mean', 'fom_std']

#plot
palette = sns.color_palette("colorblind", 3)
colors = {
    0.01: palette[0],
    0.03: palette[1],
    0.05: palette[2],
}

plt.figure(figsize=(6, 4))
for thickness in [0.01, 0.03, 0.05]:
    sub = summary[np.isclose(summary['thickness'], thickness, rtol=1e-5)]
    if sub.empty:
        print(f"⚠️ Skipping {thickness} m - no data")
        continue
    plt.errorbar(
        sub['mat_frac'], sub['fom_mean'], yerr=sub['fom_std'],
        label=f'{thickness*1000:.0f} mm', capsize=4, marker='o',
        linestyle='-', color=colors.get(thickness)
    )

plt.legend(title='Thickness')
plt.title("FOM vs. material fraction (with error bars)")
plt.xlabel("Material fraction (Fgt)")
plt.ylabel("FOM (%)")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# CPU times: total: 359 ms
# Wall time: 406 ms

# %%
import seaborn as sns

# Colors from seaborn's colorblind palette
palette = sns.color_palette("colorblind", 3)
colors = {
    0.01: palette[0],  # 10 mm
    0.03: palette[1],  # 30 mm
    0.05: palette[2],  # 50 mm
}

# Unique markers and linestyles for visibility
markers = {
    0.01: 'o',   # circle
    0.03: 's',   # square
    0.05: 'D',   # diamond
}
linestyles = {
    0.01: '-',
    0.03: '--',
    0.05: '-.',
}

plt.figure(figsize=(6, 4))
for thickness in [0.01, 0.03, 0.05]:
    sub = summary[np.isclose(summary['thickness'], thickness, rtol=1e-5)]
    if sub.empty:
        print(f"⚠️ Skipping {thickness} m - no data")
        continue
    plt.errorbar(
        sub['mat_frac'], sub['fom_mean'], yerr=sub['fom_std'],
        label=f'{thickness*1000:.0f} mm',
        capsize=4,
        marker=markers[thickness],
        linestyle=linestyles[thickness],
        color=colors[thickness],
        linewidth=1.5,
        markersize=6
    )

plt.legend(title='Thickness')
plt.title("FOM vs. material fraction (with error bars)")
plt.xlabel("Material fraction (Fgt)")
plt.ylabel("FOM (%)")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(data=df, x='Fgt', y='Fmd', hue='thickness', style='alpha')
plt.plot([0, 1], [0, 1], 'k--', label='Ideal')
plt.title("Estimated vs. true material fraction")
plt.xlabel("Fgt (true)")
plt.ylabel("Fmd (estimated)")
plt.legend()
plt.tight_layout()
plt.show()
